# %% [markdown]
# ## Pederestian classifier

# %%
import extract_features
import train_model
import test_image
import test_folder
import show_results
import evaluate_results
from skimage import io

# %%
## Extracción de características
#extract_features.run()

# %%
## Entrenamiento del clasificador
#train_model.run()

# %%
## Prueba con una imagen
imagePath = 'Images/Image008.png'
img = test_image.run(imagePath)

# %%
img
#filename = 'result001'
#io.imsave('Results/'+filename, img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=830x552 at 0x202D31D0>
