# %% [markdown]
# ## Pederestian classifier

# %%
import extract_features
import train_model
import test_image
import test_folder
import show_results
import evaluate_results
from skimage import io

# %%
## Extracción de características
#extract_features.run()

# %%
## Entrenamiento del clasificador
#train_model.run()

# %%
## Prueba con una imagen
imagePath = 'Images/Image001.png'
img = test_image.run(imagePath)

# %%
filename = 'result001'
io.imsave('Results/'+filename, img)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-31999a632ddb> in <module>()
#       1 filename = 'result001'
# ----> 2 io.imsave('Results/'+filename, img)
#
# C:\Users\Camilo\AppData\Local\Programs\Python\Python27\lib\site-packages\skimage\io\_io.pyc in imsave(fname, arr, plugin, **plugin_args)
#     137         if fname.lower().endswith(('.tiff', '.tif')):
#     138             plugin = 'tifffile'
# --> 139     if is_low_contrast(arr):
#     140         warn('%s is a low contrast image' % fname)
#     141     if arr.dtype == bool:
#
# C:\Users\Camilo\AppData\Local\Programs\Python\Python27\lib\site-packages\skimage\exposure\exposure.pyc in is_low_contrast(image, fraction_threshold, lower_percentile, upper_percentile, method)
#     501         image = rgb2gray(image)
#     502
# --> 503     dlimits = dtype_limits(image, clip_negative=False)
#     504     limits = np.percentile(image, [lower_percentile, upper_percentile])
#     505     ratio = (limits[1] - limits[0]) / (dlimits[1] - dlimits[0])
#
# C:\Users\Camilo\AppData\Local\Programs\Python\Python27\lib\site-packages\skimage\util\dtype.pyc in dtype_limits(image, clip_negative)
#      55         warn('The default of `clip_negative` in `skimage.util.dtype_limits` '
#      56              'will change to `False` in version 0.15.')
# ---> 57     imin, imax = dtype_range[image.dtype.type]
#      58     if clip_negative:
#      59         imin = 0
#
# KeyError: <type 'numpy.object_'>
